# %% [markdown]
# # Pandas
# Pandas is a modern package built on top of NumPy, and provides an efficient implementation of a DataFrame. DataFrames are essentially multidimensional arrays with attached row and column labels,that allow for different data types and/or missing data. Pandas implements a number of powerful data operations familiar to users of both database frameworks and spreadsheet programs

# %% [markdown]
# *   Series
# *   DataFrame
#
#
# *   Missing value
# *   Groupby
#
# *   Merging , Joining, Concatenating
# *   Operations with Pandas
#
# *   Importing and exporting data

# %%
labels= ['a','b','c','d']
my_data = [10,20,30,40]
my_array = np.array(my_data)
my_dict = {'a': 11,'b':33,'c':55,'d':77}

# %%
pd.Series(data=my_data)

# %%
pd.Series(data = my_data, index=labels)

# %%
pd.Series(my_array)

# %% [markdown]
# # Acessing data in pandas

# %%
ser1=pd.Series(['Valmir','Humphries','Ronasia',44,100,'Joshua',3.14])
ser1

# %%
ser2=pd.Series(data=[2005,2016,1976,1997],index=['F-22A','F-35A','F-15C','B-2A'])

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno 
from scipy import stats

# %%
dataFrame = pd.read_csv("winequality-white.csv",delimiter=';')
dataFrame
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %% [markdown]
# ###### (1) PRINT THE FIRST FIVE ROWS OF THE DATASET

# %%
print("FIRST FIVE ROWS OF DATAFRAME")
firstFiverows = dataFrame.head (n=5)
firstFiverows
# Out:
# FIRST FIVE ROWS OF DATAFRAME
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.0              0.27         0.36            20.7      0.045
# 1            6.3              0.30         0.34             1.6      0.049
# 2            8.1              0.28         0.40             6.9      0.050
# 3            7.2              0.23         0.32             8.5      0.058
# 4            7.2              0.23         0.32             8.5      0.058
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 45.0                 170.0   1.0010  3.00       0.45
# 1                 14.0                 132.0   0.9940  3.30       0.49
# 2                 30.0                  97.0   0.9951  3.26       0.44
# 3                 47.0                 186.0   0.9956  3.19       0.40
# 4                 47.0                 186.0   0.9956  3.19       0.40
#
#    alcohol  quality
# 0      8.8        6
# ...

# %% [markdown]
# ###### (2) PRINT THE LAST FIVE ROWS OF THE DATASET

# %%
print ("LAST FIVE ROWS OF DATASET")
lastFiveRows = dataFrame.tail(n=5)
lastFiveRows
# Out:
# LAST FIVE ROWS OF DATASET
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
#       free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 4893                 24.0                  92.0  0.99114  3.27       0.50
# 4894                 57.0                 168.0  0.99490  3.15       0.46
# 4895                 30.0                 111.0  0.99254  2.99       0.46
# 4896                 20.0                 110.0  0.98869  3.34       0.38
# 4897                 22.0                  98.0  0.98941  3.26       0.32
#
#       alcohol  quality
# ...

# %% [markdown]
# ###### (3) FIND OUT THE TOTAL NUMBER OF ROWS AND COLUMNS OF THE DATA SET

# %%
totalColumns = 0
for number in dataFrame.columns:
    totalColumns +=1
print ("TOTAL NUMBER OF COLUMNS IN DATASET:",totalColumns)

totalRows = dataFrame.index
countRow = len(dataFrame.index)
print("TOTAL NUMBER OF ROWS IN DATASET :",countRow)
# Out:
# TOTAL NUMBER OF COLUMNS IN DATASET: 12
# TOTAL NUMBER OF ROWS IN DATASET : 4898

# %% [markdown]
# ###### (A4) FIND OUT THE COLUMNS, DATA TYPES, AND PRESENCE OF NULL VALUES OR MISSING VALUES IN THE DATA SET

# %%
dataType = dataFrame.info()

    
nullCheck = dataFrame.isnull().sum().sum()
print ("TOTAL NUMBER OF NULL VALUE IN DATASET : ",nullCheck)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB
# TOTAL NUMBER OF NULL VALUE IN DATASET :  0

# %% [markdown]
# ###### (B) UNIVARIATE ANALYSIS

# %% [markdown]
# ###### (B1) FIND OUT MISSING VALUES GRAPHICALLY

# %%
msno.bar(dataFrame,color="orange")

# %% [markdown]
# ###### (B2) FIND OUT THE NUMBER OF ROWS, MEAN, STD DEVIATION, MIN, Q1, Q2, Q3, MAX VALUES FOR EACH VARIABLE. DOCUMENT YOUR OBSERVATIONS TO CHECK IF THE OUTLIERS ARE PRESENT IN THE DATA SET

# %%
dataFrame.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    4898.000000       4898.000000  4898.000000     4898.000000
# mean        6.854788          0.278241     0.334192        6.391415
# std         0.843868          0.100795     0.121020        5.072058
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.300000          0.210000     0.270000        1.700000
# 50%         6.800000          0.260000     0.320000        5.200000
# 75%         7.300000          0.320000     0.390000        9.900000
# max        14.200000          1.100000     1.660000       65.800000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  4898.000000          4898.000000           4898.000000  4898.000000
# mean      0.045772            35.308085            138.360657     0.994027
# std       0.021848            17.007137             42.498065     0.002991
# ...

# %% [markdown]
# ###### (B3) DRAW THE HISTOGRAM, KERNEL DENSITY ESTIMATE (KDE) TO CHECK THE DISTRIBUTION AND SKEWNESS FOR EACH VARIABLE. DOCUMENT YOUR OBSERVATION

# %% [markdown]
# ###### (I) FOR FIXED ACIDITY

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR FIXED ACIDITY")
sns.kdeplot(dataFrame['fixed acidity'])
plt.show()
dataFrame['fixed acidity'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR FIXED ACIDITY
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (II) VOLATILE ACIDITY

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR VOLATILE ACIDITY")
sns.kdeplot(dataFrame['volatile acidity'])
plt.show()
dataFrame['fixed acidity'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR VOLATILE ACIDITY
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (III) CITRIC ACID

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR CITRIC ACID")
sns.kdeplot(dataFrame['citric acid'])
plt.show()
dataFrame['citric acid'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR CITRIC ACID
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (IV) RESIDUAL SUGAR

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR RESIDUAL SUGAR")
sns.kdeplot(dataFrame['residual sugar'])
plt.show()
dataFrame['residual sugar'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR RESIDUAL SUGAR
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (V) CHLORIDES

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR CHLORIDES")
sns.kdeplot(dataFrame['chlorides'])
plt.show()
dataFrame['chlorides'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR CHLORIDES
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (VI) FREE SULFUR DIOXIDE

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR FREE SULFUR DIOXIDE")
sns.kdeplot(dataFrame['free sulfur dioxide'])
plt.show()
dataFrame['free sulfur dioxide'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR FREE SULFUR DIOXIDE
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (VII) TOTAL SULFUR DIOXIDE

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR TOTAL SULFUR DIOXIDE")
sns.kdeplot(dataFrame['total sulfur dioxide'])
plt.show()
dataFrame['total sulfur dioxide'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR TOTAL SULFUR DIOXIDE
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (VIII) DENSITY

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR DENSITY")
sns.kdeplot(dataFrame['density'])
plt.show()
dataFrame['density'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR DENSITY
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (IX) pH

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR pH")
sns.kdeplot(dataFrame['pH'])
plt.show()
dataFrame['pH'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR pH
# Skewed Right,[Median<mean]

# %% [markdown]
# ######  (X) SULPHATES

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR SULPHATES")
sns.kdeplot(dataFrame['sulphates'])
plt.show()
dataFrame['sulphates'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR SULPHATES
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (XI) ALCOHOL

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR ALCOHOL")
sns.kdeplot(dataFrame['alcohol'])
plt.show()
dataFrame['alcohol'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR ALCOHOL
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (XII) QUALITY

# %%
print ("HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR QUALITY")
sns.kdeplot(dataFrame['quality'])
plt.show()
dataFrame['quality'].hist(bins=30)
print('Skewed Right,[Median<mean]')
# Out:
# HISTOGRAM AND KERNAL DENSITY ESTIMATE FOR QUALITY
# Skewed Right,[Median<mean]

# %% [markdown]
# ###### (B4) CREATE A FREQUENCY DISTRIBUTION TABLE AND BAR CHART FOR THE OUTPUT VARIABLE

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# ###### (I) FIXED ACIDITY

# %%
print('FREQUENCY TABLE FOR FIXED ACIDITY')
fixedAcidity = pd.crosstab(index=dataFrame['fixed acidity'],columns='count')
print(fixedAcidity)

print("\nBAR GRAPH FOR FIXED ACIDITY")
fixedAcidity.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR FIXED ACIDITY
# col_0          count
# fixed acidity
# 3.8                1
# 3.9                1
# 4.2                2
# 4.4                3
# 4.5                1
# ...              ...
# 10.2               1
# 10.3               2
# 10.7               2
# 11.8               1
# 14.2               1
#
# [68 rows x 1 columns]
#
# BAR GRAPH FOR FIXED ACIDITY

# %% [markdown]
# ###### (II) VOLATILE ACIDITY

# %%
print('FREQUENCY TABLE FOR VOLATILE ACIDITY')
volatileAcidity = pd.crosstab(index=dataFrame['volatile acidity'],columns='count')
print(volatileAcidity)

print("\nBAR GRAPH FOR VOLATILE ACIDITY")
volatileAcidity.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR VOLATILE ACIDITY
# col_0             count
# volatile acidity
# 0.080                 4
# 0.085                 1
# 0.090                 1
# 0.100                 6
# 0.105                 6
# ...                 ...
# 0.910                 1
# 0.930                 1
# 0.965                 1
# 1.005                 1
# 1.100                 1
#
# [125 rows x 1 columns]
#
# BAR GRAPH FOR VOLATILE ACIDITY

# %% [markdown]
# ###### (III) CITRIC ACID

# %%
print('FREQUENCY TABLE FOR CITRIC ACID ')
citricAcid = pd.crosstab(index=dataFrame['citric acid'],columns='count')
print(citricAcid)

print("\nBAR GRAPH FOR CITRIC ACID ")
citricAcid.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR CITRIC ACID
# col_0        count
# citric acid
# 0.00            19
# 0.01             7
# 0.02             6
# 0.03             2
# 0.04            12
# ...            ...
# 0.91             2
# 0.99             1
# 1.00             5
# 1.23             1
# 1.66             1
#
# [87 rows x 1 columns]
#
# BAR GRAPH FOR CITRIC ACID

# %% [markdown]
# ###### (IV) RESIDUAL SUGAR

# %%
print('FREQUENCY TABLE FOR RESIDUAL SUGAR ')
residualSugar = pd.crosstab(index=dataFrame['residual sugar'],columns='count')
print(residualSugar)

print("\nBAR GRAPH FOR RESIDUAL SUGAR ")
residualSugar.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR RESIDUAL SUGAR
# col_0           count
# residual sugar
# 0.60                2
# 0.70                7
# 0.80               25
# 0.90               39
# 0.95                4
# ...               ...
# 22.60               1
# 23.50               1
# 26.05               2
# 31.60               2
# 65.80               1
#
# [310 rows x 1 columns]
#
# BAR GRAPH FOR RESIDUAL SUGAR

# %% [markdown]
# ###### (V) CHLORIDES

# %%
print('FREQUENCY TABLE FOR CHLORIDES ')
Chloride = pd.crosstab(index=dataFrame['chlorides'],columns='count')
print(Chloride)

print("\nBAR GRAPH FOR CHLORIDES ")
Chloride.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR CHLORIDES
# col_0      count
# chlorides
# 0.009          1
# 0.012          1
# 0.013          1
# 0.014          4
# 0.015          4
# ...          ...
# 0.255          1
# 0.271          1
# 0.290          1
# 0.301          1
# 0.346          1
#
# [160 rows x 1 columns]
#
# BAR GRAPH FOR CHLORIDES

# %% [markdown]
# ###### (VI) FREE SULFUR DIOXIDE

# %%
print('FREQUENCY TABLE FOR FREE SULFUR DIOXIDE ')
freeSulfurDioxide = pd.crosstab(index=dataFrame['free sulfur dioxide'],columns='count')
print(freeSulfurDioxide)

print("\nBAR GRAPH FOR FREE SULFUR DIOXIDE ")
freeSulfurDioxide.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR FREE SULFUR DIOXIDE
# col_0                count
# free sulfur dioxide
# 2.0                      1
# 3.0                     10
# 4.0                     11
# 5.0                     25
# 6.0                     32
# ...                    ...
# 128.0                    1
# 131.0                    1
# 138.5                    1
# 146.5                    1
# 289.0                    1
#
# [132 rows x 1 columns]
#
# BAR GRAPH FOR FREE SULFUR DIOXIDE

# %% [markdown]
# ###### (VII) TOTAL SULFUR DIOXIDE

# %%
print('FREQUENCY TABLE FOR TOTAL SULFUR DIOXIDE ')
totalSulfurDioxide = pd.crosstab(index=dataFrame['free sulfur dioxide'],columns='count')
print(totalSulfurDioxide)

print("\nBAR GRAPH FOR TOTAL SULFUR DIOXIDE")
totalSulfurDioxide.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR TOTAL SULFUR DIOXIDE
# col_0                count
# free sulfur dioxide
# 2.0                      1
# 3.0                     10
# 4.0                     11
# 5.0                     25
# 6.0                     32
# ...                    ...
# 128.0                    1
# 131.0                    1
# 138.5                    1
# 146.5                    1
# 289.0                    1
#
# [132 rows x 1 columns]
#
# BAR GRAPH FOR TOTAL SULFUR DIOXIDE

# %% [markdown]
# ###### (VIII) DENSITY

# %%
print('FREQUENCY TABLE FOR DENSITY')
Density = pd.crosstab(index=dataFrame['density'],columns='count')
print(Density)

print("\nBAR GRAPH FOR DENSITY")
Density.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR DENSITY
# col_0    count
# density
# 0.98711      1
# 0.98713      1
# 0.98722      1
# 0.98740      1
# 0.98742      2
# ...        ...
# 1.00240      1
# 1.00241      1
# 1.00295      2
# 1.01030      2
# 1.03898      1
#
# [890 rows x 1 columns]
#
# BAR GRAPH FOR DENSITY

# %% [markdown]
# ###### (IX) pH

# %%
print('FREQUENCY TABLE FOR PH')
pH = pd.crosstab(index=dataFrame['pH'],columns='count')
print(pH)

print("\nBAR GRAPH FOR PH")
pH.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR PH
# col_0  count
# pH
# 2.72       1
# 2.74       1
# 2.77       1
# 2.79       3
# 2.80       3
# ...      ...
# 3.77       2
# 3.79       1
# 3.80       2
# 3.81       1
# 3.82       1
#
# [103 rows x 1 columns]
#
# BAR GRAPH FOR PH

# %% [markdown]
# ###### (X) SULPHATES

# %%
print('FREQUENCY TABLE FOR SULPHATES')
Sulphate = pd.crosstab(index=dataFrame['sulphates'],columns='count')
print(Sulphate)

print("\nBAR GRAPH FOR SULPHATES")
Sulphate.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR SULPHATES
# col_0      count
# sulphates
# 0.22           1
# 0.23           1
# 0.25           4
# 0.26           4
# 0.27          13
# ...          ...
# 0.99           1
# 1.00           1
# 1.01           1
# 1.06           1
# 1.08           1
#
# [79 rows x 1 columns]
#
# BAR GRAPH FOR SULPHATES

# %% [markdown]
# ###### (XI) ALCOHOL

# %%
print('FREQUENCY TABLE FOR ALCOHOL')
Alcohol = pd.crosstab(index=dataFrame['alcohol'],columns='count')
print(Alcohol)

print("\nBAR GRAPH FOR ALCOHOL")
Alcohol.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR ALCOHOL
# col_0    count
# alcohol
# 8.00         2
# 8.40         3
# 8.50         9
# 8.60        23
# 8.70        78
# ...        ...
# 13.80        2
# 13.90        3
# 14.00        5
# 14.05        1
# 14.20        1
#
# [103 rows x 1 columns]
#
# BAR GRAPH FOR ALCOHOL

# %% [markdown]
# ###### (XII) QUALITY

# %%
print('FREQUENCY TABLE FOR QULAITY')
Quality = pd.crosstab(index=dataFrame['quality'],columns='count')
print(Quality)

print("\nBAR GRAPH FOR QULAITY")
Quality.plot.bar(figsize =(25,15),rot = 0 )
# Out:
# FREQUENCY TABLE FOR QULAITY
# col_0    count
# quality
# 3           20
# 4          163
# 5         1457
# 6         2198
# 7          880
# 8          175
# 9            5
#
# BAR GRAPH FOR QULAITY

# %%
dataFrame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4898 entries, 0 to 4897
# Data columns (total 12 columns):
# fixed acidity           4898 non-null float64
# volatile acidity        4898 non-null float64
# citric acid             4898 non-null float64
# residual sugar          4898 non-null float64
# chlorides               4898 non-null float64
# free sulfur dioxide     4898 non-null float64
# total sulfur dioxide    4898 non-null float64
# density                 4898 non-null float64
# pH                      4898 non-null float64
# sulphates               4898 non-null float64
# alcohol                 4898 non-null float64
# quality                 4898 non-null int64
# dtypes: float64(11), int64(1)
# memory usage: 459.3 KB

# %% [markdown]
# ###### (B5)DRAW BOXPLOT FOR EACH VARIABLE AND IDENTIFY THE IQR AND OUTLINERS

# %% [markdown]
# ###### (I) FIXED ACIDITY

# %%
sns.boxplot(dataFrame["fixed acidity"])
plt.show() 


IQR = stats.iqr(dataFrame['fixed acidity'],axis=0) 
print ('\nIQR OF FIXED ACIDITY : {I:1.3f}'.format (I = IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR OF FIXED ACIDITY : 1.000
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (II) VOLATILE ACIDITY

# %%
sns.boxplot(dataFrame["volatile acidity"])
plt.show() 


IQR = stats.iqr(dataFrame['volatile acidity'],axis=0)
print("\nIQR FOR VOLATILE ACIDITY : {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR FOR VOLATILE ACIDITY : 0.110
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (III) CITRIC ACID

# %%
sns.boxplot(dataFrame["citric acid"])
plt.show() 


IQR = stats.iqr(dataFrame['citric acid'],axis=0)
print("\nIQR FOR CITRIC ACID : {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR FOR CITRIC ACID : 0.120
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (IV) RESIDUAL SUGAR

# %%
sns.boxplot(dataFrame["residual sugar"])
plt.show() 


IQR = stats.iqr(dataFrame['residual sugar'],axis=0)
print("\nIQR FOR RESIDUAL SUGAR : {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR FOR RESIDUAL SUGAR : 8.200
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (V) CHLORIDES

# %%
sns.boxplot(dataFrame["chlorides"])
plt.show() 


IQR = stats.iqr(dataFrame['chlorides'],axis=0)
print("\nIQR FOR CHLORIDES: {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR FOR CHLORIDES: 0.014
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (VI) FREE SULFUR DIOXIDE

# %%
sns.boxplot(dataFrame["free sulfur dioxide"])
plt.show() 


IQR = stats.iqr(dataFrame['free sulfur dioxide'],axis=0)
print("\nIQR FOR FREE SULFUR DIOXIDE: {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR FOR FREE SULFUR DIOXIDE: 23.000
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (VII) TOTAL SULFUR DIOXIDE

# %%
sns.boxplot(dataFrame["total sulfur dioxide"])
plt.show() 


IQR = stats.iqr(dataFrame['total sulfur dioxide'],axis=0)
print("\nIQR FOR TOTAL SULFUR DIOXIDE: {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR FOR TOTAL SULFUR DIOXIDE: 59.000
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (VIII) DENSITY

# %%
sns.boxplot(dataFrame["density"])
plt.show() 


IQR = stats.iqr(dataFrame['density'],axis=0)
print("\nIQR FOR DENSITY: {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR FOR DENSITY: 0.004
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (IX) pH

# %%
sns.boxplot(dataFrame["pH"])
plt.show() 


IQR = stats.iqr(dataFrame['pH'],axis=0)
print("\nIQR FOR pH: {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR FOR pH: 0.190
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (X) SULPHATES

# %%
sns.boxplot(dataFrame["sulphates"])
plt.show() 


IQR = stats.iqr(dataFrame['sulphates'],axis=0)
print("\nIQR FOR SULPHATES: {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE MANY OUTLINERS")
# Out:
# IQR FOR SULPHATES: 0.140
#
# THERE ARE MANY OUTLINERS

# %% [markdown]
# ###### (XI) ALCOHOL

# %%
sns.boxplot(dataFrame["alcohol"])
plt.show() 


IQR = stats.iqr(dataFrame['alcohol'],axis=0)
print("\nIQR FOR ALCOHOL: {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE NO OUTLINERS")
# Out:
# IQR FOR ALCOHOL: 1.900
#
# THERE ARE NO OUTLINERS

# %% [markdown]
# ###### (XII) QUALITY

# %%
sns.boxplot(dataFrame["quality"])
plt.show() 


IQR = stats.iqr(dataFrame['quality'],axis=0)
print("\nIQR FOR QUALITY: {I:1.3f} ".format (I=IQR))

print ("\nTHERE ARE SOME OUTLINERS")
# Out:
# IQR FOR QUALITY: 1.000
#
# THERE ARE SOME OUTLINERS

# %% [markdown]
# ## C.MULTIRATIVE ANALYSIS

# %% [markdown]
# ###### A. DRAW THE CORRELATION AND IDENTIFY THE VARIABLES THAT ARE CORRELATED TO EACH OTHER

# %%
fig, ax = plt.subplots(figsize=(20,15))
sns.heatmap(dataFrame.corr(), annot = True,ax=ax)
